# %%
items = ["bread","pasta","veggies","fruits"]
items
items[0:2]
items.append("butter")
items
items.remove("butter")
items.insert(1,"butter")
items
items[1] = "cheese"
items
items[3:] = ["almonds"]
items
expenses = [30,1200,45,300]
expenses.sort(reverse=True)
expenses
items.sort(reverse=True)
items
bathroom_items = ["shampoo","soap"]
final_items = bathroom_items + items + expenses
final_items
len(final_items)
final_items.clear()
final_items
# Out:
# []
